# %%
from fastai import *
from fastai.vision import *
import torch.onnx
from torch.autograd import Variable
import scipy.stats as stats
import netron

# %%
import os

os.environ["TORCH_HOME"] = "/media/subhaditya/DATA/COSMO/Datasets-Useful"

# %%
# path = untar_data(URLs.CIFAR_100)
path = Path('data/CCSN/')

# %%
data = (
    (
        ImageList.from_folder(path)
        .split_by_rand_pct()
        .label_from_folder()
        .transform(get_transforms(), size=128)
    )
    .databunch(bs=64)
    .normalize(imagenet_stats)
)

# %%
data.show_batch(4)

# %%
data.c
# Out:
# 11

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (48000 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# cloud,cloud,cloud,cloud,cloud
# Path: /home/subhaditya/.fastai/data/cifar100;
#
# Valid: LabelList (12000 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# shark,bicycle,pickup_truck,flatfish,girl
# Path: /home/subhaditya/.fastai/data/cifar100;
#
# Test: None

# %% [markdown]
# # LeNet

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, bias=False, **kwargs)
        self.bn = nn.BatchNorm2d(out_channels, eps=0.001)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        return F.relu(x, inplace=True)

# %%
class InceptionAux(nn.Module):
    def __init__(self, in_channels, num_classes=11, conv_block=None):
        super(InceptionAux, self).__init__()
        conv_block = BasicConv2d
        self.conv = conv_block(in_channels, 128, kernel_size=1)
        self.fc1 = nn.Linear(2048, 1024)
        self.fc2 = nn.Linear(1024, num_classes)

    def forward(self, x):
        x = F.adaptive_avg_pool2d(x, (4, 4))
        x = self.conv(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x, inplace=True)
        x = F.dropout(x, 0.7)
        x = self.fc2(x)
        return x

# %%
class Inception(nn.Module):
    def __init__(
        self,
        in_channels,
        ch1x1,
        ch3x3red,
        ch3x3,
        ch5x5red,
        ch5x5,
        pool_proj,
        conv_block=None,
    ):
        super(Inception, self).__init__()
        conv_block = BasicConv2d
        self.branch1 = conv_block(in_channels, ch1x1, kernel_size=1)
        self.branch2 = nn.Sequential(
            conv_block(in_channels, ch3x3red, kernel_size=1),
            conv_block(ch3x3red, ch3x3, kernel_size=3, padding=1),
        )
        self.branch3 = nn.Sequential(
            conv_block(in_channels, ch5x5red, kernel_size=1),
            conv_block(ch5x5red, ch5x5, kernel_size=3, padding=1),
        )
        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1, ceil_mode=True),
            conv_block(in_channels, pool_proj, kernel_size=1),
        )

    def forward(self, x):
        outputs = [self.branch1(x), self.branch2(x), self.branch3(x), self.branch4(x)]
        return torch.cat(outputs, 1)

# %%
class Model(nn.Module):
    __constants__ = ["aux_logits", "transform_input"]

    def __init__(
        self,
        num_classes=11,
        aux_logits=True,
        transform_input=False,
        init_weights=True,
        blocks=None,
    ):
        super(Model, self).__init__()
        conv_block = BasicConv2d
        inception_block = Inception
        inception_aux_block = InceptionAux

        self.aux_logits = aux_logits
        self.transform_input = transform_input
        self.maxpool = nn.MaxPool2d(3, stride=2, ceil_mode=True)
        self.conv1 = conv_block(3, 64, kernel_size=7, stride=2, padding=3)

        self.conv2 = conv_block(64, 64, kernel_size=1)
        self.conv3 = conv_block(64, 192, kernel_size=3, padding=1)

        #                                  in_channels,ch1x1,ch3x3red,ch3x3,ch5x5red,ch5x5,pool_proj
        self.inception3a = inception_block(192, 64, 96, 128, 16, 32, 32)
        self.inception3b = inception_block(256, 128, 128, 192, 32, 96, 64)

        self.inception4a = inception_block(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = inception_block(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = inception_block(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = inception_block(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = inception_block(528, 256, 160, 320, 32, 128, 128)

        self.inception5a = inception_block(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = inception_block(832, 384, 192, 384, 48, 128, 128)
        self.aux1 = inception_aux_block(512, num_classes)
        self.aux2 = inception_aux_block(528, num_classes)

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(1024, num_classes)
        self._initialize_weights()

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):

                X = stats.truncnorm(-2, 2, scale=0.01)
                values = torch.as_tensor(X.rvs(m.weight.numel()), dtype=m.weight.dtype)
                values = values.view(m.weight.size())
                with torch.no_grad():
                    m.weight.copy_(values)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.conv1(x)
        x = self.maxpool(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.maxpool(x)
        x = self.inception3a(x)
        x = self.inception3b(x)
        x = self.maxpool(x)
        x = self.inception4a(x)
        aux1 = self.aux1(x)
        x = self.inception4b(x)
        x = self.inception4c(x)
        x = self.inception4d(x)
        aux2 = self.aux2(x)

        x = self.inception4e(x)
        x = self.maxpool(x)
        x = self.inception5a(x)
        x = self.inception5b(x)

        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        x = self.fc(x)
        #         return x, aux2, aux1

        return x

# %%
learn = None
gc.collect()
# Out:
# 35377

# %%
learn = Learner(
    data,
    Model(),
    metrics=[accuracy, error_rate],
    opt_func=AdamW,
    callback_fns=ShowGraph,
).to_fp16()

# %%
learn.summary()
# Out:
# Model
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# MaxPool2d            [832, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [64, 64, 64]         9,408      True
# ______________________________________________________________________
# BatchNorm2d          [64, 64, 64]         128        True
# ______________________________________________________________________
# Conv2d               [64, 32, 32]         4,096      True
# ______________________________________________________________________
# BatchNorm2d          [64, 32, 32]         128        True
# ______________________________________________________________________
# Conv2d               [192, 32, 32]        110,592    True
# ______________________________________________________________________
# BatchNorm2d          [192, 32, 32]        384        True
# ______________________________________________________________________
# Conv2d               [64, 16, 16]         12,288     True
# ______________________________________________________________________
# BatchNorm2d          [64, 16, 16]         128        True
# ______________________________________________________________________
# Conv2d               [96, 16, 16]         18,432     True
# ______________________________________________________________________
# BatchNorm2d          [96, 16, 16]         192        True
# ______________________________________________________________________
# Conv2d               [128, 16, 16]        110,592    True
# ______________________________________________________________________
# BatchNorm2d          [128, 16, 16]        256        True
# ______________________________________________________________________
# Conv2d               [16, 16, 16]         3,072      True
# ______________________________________________________________________
# BatchNorm2d          [16, 16, 16]         32         True
# ______________________________________________________________________
# Conv2d               [32, 16, 16]         4,608      True
# ______________________________________________________________________
# BatchNorm2d          [32, 16, 16]         64         True
# ______________________________________________________________________
# MaxPool2d            [192, 16, 16]        0          False
# ______________________________________________________________________
# Conv2d               [32, 16, 16]         6,144      True
# ______________________________________________________________________
# BatchNorm2d          [32, 16, 16]         64         True
# ______________________________________________________________________
# Conv2d               [128, 16, 16]        32,768     True
# ______________________________________________________________________
# BatchNorm2d          [128, 16, 16]        256        True
# ______________________________________________________________________
# Conv2d               [128, 16, 16]        32,768     True
# ______________________________________________________________________
# BatchNorm2d          [128, 16, 16]        256        True
# ______________________________________________________________________
# Conv2d               [192, 16, 16]        221,184    True
# ______________________________________________________________________
# BatchNorm2d          [192, 16, 16]        384        True
# ______________________________________________________________________
# Conv2d               [32, 16, 16]         8,192      True
# ______________________________________________________________________
# BatchNorm2d          [32, 16, 16]         64         True
# ______________________________________________________________________
# Conv2d               [96, 16, 16]         27,648     True
# ______________________________________________________________________
# BatchNorm2d          [96, 16, 16]         192        True
# ______________________________________________________________________
# MaxPool2d            [256, 16, 16]        0          False
# ______________________________________________________________________
# Conv2d               [64, 16, 16]         16,384     True
# ______________________________________________________________________
# BatchNorm2d          [64, 16, 16]         128        True
# ______________________________________________________________________
# Conv2d               [192, 8, 8]          92,160     True
# ______________________________________________________________________
# BatchNorm2d          [192, 8, 8]          384        True
# ______________________________________________________________________
# Conv2d               [96, 8, 8]           46,080     True
# ______________________________________________________________________
# BatchNorm2d          [96, 8, 8]           192        True
# ______________________________________________________________________
# Conv2d               [208, 8, 8]          179,712    True
# ______________________________________________________________________
# BatchNorm2d          [208, 8, 8]          416        True
# ______________________________________________________________________
# Conv2d               [16, 8, 8]           7,680      True
# ______________________________________________________________________
# BatchNorm2d          [16, 8, 8]           32         True
# ______________________________________________________________________
# Conv2d               [48, 8, 8]           6,912      True
# ______________________________________________________________________
# BatchNorm2d          [48, 8, 8]           96         True
# ______________________________________________________________________
# MaxPool2d            [480, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [64, 8, 8]           30,720     True
# ______________________________________________________________________
# BatchNorm2d          [64, 8, 8]           128        True
# ______________________________________________________________________
# Conv2d               [160, 8, 8]          81,920     True
# ______________________________________________________________________
# BatchNorm2d          [160, 8, 8]          320        True
# ______________________________________________________________________
# Conv2d               [112, 8, 8]          57,344     True
# ______________________________________________________________________
# BatchNorm2d          [112, 8, 8]          224        True
# ______________________________________________________________________
# Conv2d               [224, 8, 8]          225,792    True
# ______________________________________________________________________
# BatchNorm2d          [224, 8, 8]          448        True
# ______________________________________________________________________
# Conv2d               [24, 8, 8]           12,288     True
# ______________________________________________________________________
# BatchNorm2d          [24, 8, 8]           48         True
# ______________________________________________________________________
# Conv2d               [64, 8, 8]           13,824     True
# ______________________________________________________________________
# BatchNorm2d          [64, 8, 8]           128        True
# ______________________________________________________________________
# MaxPool2d            [512, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [64, 8, 8]           32,768     True
# ______________________________________________________________________
# BatchNorm2d          [64, 8, 8]           128        True
# ______________________________________________________________________
# Conv2d               [128, 8, 8]          65,536     True
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 8]          256        True
# ______________________________________________________________________
# Conv2d               [128, 8, 8]          65,536     True
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 8]          256        True
# ______________________________________________________________________
# Conv2d               [256, 8, 8]          294,912    True
# ______________________________________________________________________
# BatchNorm2d          [256, 8, 8]          512        True
# ______________________________________________________________________
# Conv2d               [24, 8, 8]           12,288     True
# ______________________________________________________________________
# BatchNorm2d          [24, 8, 8]           48         True
# ______________________________________________________________________
# Conv2d               [64, 8, 8]           13,824     True
# ______________________________________________________________________
# BatchNorm2d          [64, 8, 8]           128        True
# ______________________________________________________________________
# MaxPool2d            [512, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [64, 8, 8]           32,768     True
# ______________________________________________________________________
# BatchNorm2d          [64, 8, 8]           128        True
# ______________________________________________________________________
# Conv2d               [112, 8, 8]          57,344     True
# ______________________________________________________________________
# BatchNorm2d          [112, 8, 8]          224        True
# ______________________________________________________________________
# Conv2d               [144, 8, 8]          73,728     True
# ______________________________________________________________________
# BatchNorm2d          [144, 8, 8]          288        True
# ______________________________________________________________________
# Conv2d               [288, 8, 8]          373,248    True
# ______________________________________________________________________
# BatchNorm2d          [288, 8, 8]          576        True
# ______________________________________________________________________
# Conv2d               [32, 8, 8]           16,384     True
# ______________________________________________________________________
# BatchNorm2d          [32, 8, 8]           64         True
# ______________________________________________________________________
# Conv2d               [64, 8, 8]           18,432     True
# ______________________________________________________________________
# BatchNorm2d          [64, 8, 8]           128        True
# ______________________________________________________________________
# MaxPool2d            [512, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [64, 8, 8]           32,768     True
# ______________________________________________________________________
# BatchNorm2d          [64, 8, 8]           128        True
# ______________________________________________________________________
# Conv2d               [256, 8, 8]          135,168    True
# ______________________________________________________________________
# BatchNorm2d          [256, 8, 8]          512        True
# ______________________________________________________________________
# Conv2d               [160, 8, 8]          84,480     True
# ______________________________________________________________________
# BatchNorm2d          [160, 8, 8]          320        True
# ______________________________________________________________________
# Conv2d               [320, 8, 8]          460,800    True
# ______________________________________________________________________
# BatchNorm2d          [320, 8, 8]          640        True
# ______________________________________________________________________
# Conv2d               [32, 8, 8]           16,896     True
# ______________________________________________________________________
# BatchNorm2d          [32, 8, 8]           64         True
# ______________________________________________________________________
# Conv2d               [128, 8, 8]          36,864     True
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 8]          256        True
# ______________________________________________________________________
# MaxPool2d            [528, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [128, 8, 8]          67,584     True
# ______________________________________________________________________
# BatchNorm2d          [128, 8, 8]          256        True
# ______________________________________________________________________
# Conv2d               [256, 4, 4]          212,992    True
# ______________________________________________________________________
# BatchNorm2d          [256, 4, 4]          512        True
# ______________________________________________________________________
# Conv2d               [160, 4, 4]          133,120    True
# ______________________________________________________________________
# BatchNorm2d          [160, 4, 4]          320        True
# ______________________________________________________________________
# Conv2d               [320, 4, 4]          460,800    True
# ______________________________________________________________________
# BatchNorm2d          [320, 4, 4]          640        True
# ______________________________________________________________________
# Conv2d               [32, 4, 4]           26,624     True
# ______________________________________________________________________
# BatchNorm2d          [32, 4, 4]           64         True
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          36,864     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# MaxPool2d            [832, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          106,496    True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# Conv2d               [384, 4, 4]          319,488    True
# ______________________________________________________________________
# BatchNorm2d          [384, 4, 4]          768        True
# ______________________________________________________________________
# Conv2d               [192, 4, 4]          159,744    True
# ______________________________________________________________________
# BatchNorm2d          [192, 4, 4]          384        True
# ______________________________________________________________________
# Conv2d               [384, 4, 4]          663,552    True
# ______________________________________________________________________
# BatchNorm2d          [384, 4, 4]          768        True
# ______________________________________________________________________
# Conv2d               [48, 4, 4]           39,936     True
# ______________________________________________________________________
# BatchNorm2d          [48, 4, 4]           96         True
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          55,296     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# MaxPool2d            [832, 4, 4]          0          False
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          106,496    True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          65,536     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# Linear               [1024]               2,098,176  True
# ______________________________________________________________________
# Linear               [11]                 11,275     True
# ______________________________________________________________________
# Conv2d               [128, 4, 4]          67,584     True
# ______________________________________________________________________
# BatchNorm2d          [128, 4, 4]          256        True
# ______________________________________________________________________
# Linear               [1024]               2,098,176  True
# ______________________________________________________________________
# Linear               [11]                 11,275     True
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1024, 1, 1]         0          False
# ______________________________________________________________________
# Dropout              [1024]               0          False
# ______________________________________________________________________
# Linear               [11]                 11,275     True
# ______________________________________________________________________
#
# Total params: 9,963,713
# Total trainable params: 9,963,713
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied
#     MixedPrecision

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [3/4 00:14<00:04]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.387879</td>
#       <td>#na#</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.277920</td>
#       <td>#na#</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.835159</td>
#       <td>#na#</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='30', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       16.67% [5/30 00:01<00:08 5.1779]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(10, 1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.358814</td>
#       <td>2.388560</td>
#       <td>0.086066</td>
#       <td>0.913934</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.216415</td>
#       <td>2.273426</td>
#       <td>0.176230</td>
#       <td>0.823770</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.082742</td>
#       <td>2.028439</td>
#       <td>0.280738</td>
#       <td>0.719262</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.983943</td>
#       <td>1.953819</td>
#       <td>0.311475</td>
#       <td>0.688525</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.904552</td>
#       <td>1.934814</td>
#       <td>0.338115</td>
#       <td>0.661885</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.822465</td>
#       <td>1.878703</td>
#       <td>0.325820</td>
#       <td>0.674180</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.727237</td>
#       <td>1.732535</td>
#       <td>0.405738</td>
#       <td>0.594262</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.638321</td>
#       <td>1.698255</td>
#       <td>0.387295</td>
#       <td>0.612705</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.538563</td>
#       <td>1.659182</td>
#       <td>0.413934</td>
#       <td>0.586066</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.465304</td>
#       <td>1.658841</td>
#       <td>0.409836</td>
#       <td>0.590164</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [3/4 00:16<00:05]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.384603</td>
#       <td>#na#</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.750524</td>
#       <td>#na#</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.833930</td>
#       <td>#na#</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='30', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       13.33% [4/30 00:01<00:10 4.6822]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()
learn.fit_one_cycle(10, 1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.368401</td>
#       <td>1.659415</td>
#       <td>0.409836</td>
#       <td>0.590164</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.351700</td>
#       <td>1.659784</td>
#       <td>0.409836</td>
#       <td>0.590164</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.352615</td>
#       <td>1.662082</td>
#       <td>0.411885</td>
#       <td>0.588115</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.334389</td>
#       <td>1.625910</td>
#       <td>0.436475</td>
#       <td>0.563525</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.310767</td>
#       <td>1.642300</td>
#       <td>0.450820</td>
#       <td>0.549180</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.273807</td>
#       <td>1.632186</td>
#       <td>0.438525</td>
#       <td>0.561475</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.246299</td>
#       <td>1.642389</td>
#       <td>0.440574</td>
#       <td>0.559426</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.215458</td>
#       <td>1.629112</td>
#       <td>0.436475</td>
#       <td>0.563525</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.202787</td>
#       <td>1.631206</td>
#       <td>0.442623</td>
#       <td>0.557377</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.179422</td>
#       <td>1.629892</td>
#       <td>0.450820</td>
#       <td>0.549180</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(20, 1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.189111</td>
#       <td>1.663907</td>
#       <td>0.415984</td>
#       <td>0.584016</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.181864</td>
#       <td>1.668212</td>
#       <td>0.430328</td>
#       <td>0.569672</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.212536</td>
#       <td>1.918446</td>
#       <td>0.377049</td>
#       <td>0.622951</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1
td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.436345</td>
#       <td>2.567520</td>
#       <td>0.372951</td>
#       <td>0.627049</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.393019</td>
#       <td>2.455399</td>
#       <td>0.420082</td>
#       <td>0.579918</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.378325</td>
#       <td>2.355045</td>
#       <td>0.444672</td>
#       <td>0.555328</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.356805</td>
#       <td>2.353192</td>
#       <td>0.422131</td>
#       <td>0.577869</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.328854</td>
#       <td>2.575245</td>
#       <td>0.413934</td>
#       <td>0.586066</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.313458</td>
#       <td>2.450889</td>
#       <td>0.438525</td>
#       <td>0.561475</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.315332</td>
#       <td>2.777084</td>
#       <td>0.411885</td>
#       <td>0.588115</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.310448</td>
#       <td>2.662471</td>
#       <td>0.413934</td>
#       <td>0.586066</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.292604</td>
#       <td>2.498057</td>
#       <td>0.428279</td>
#       <td>0.571721</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.262540</td>
#       <td>2.486500</td>
#       <td>0.403689</td>
#       <td>0.596311</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.262686</td>
#       <td>2.585132</td>
#       <td>0.424180</td>
#       <td>0.575820</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.233779</td>
#       <td>2.364581</td>
#       <td>0.448770</td>
#       <td>0.551230</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.210346</td>
#       <td>2.478943</td>
#       <td>0.463115</td>
#       <td>0.536885</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.198158</td>
#       <td>2.559703</td>
#       <td>0.436475</td>
#       <td>0.563525</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.191303</td>
#       <td>2.666147</td>
#       <td>0.442623</td>
#       <td>0.557377</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.176988</td>
#       <td>2.564059</td>
#       <td>0.448770</td>
#       <td>0.551230</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.158738</td>
#       <td>2.522152</td>
#       <td>0.465164</td>
#       <td>0.534836</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.141708</td>
#       <td>2.551914</td>
#       <td>0.446721</td>
#       <td>0.553279</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.135238</td>
#       <td>2.452355</td>
#       <td>0.475410</td>
#       <td>0.524590</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.123894</td>
#       <td>2.495900</td>
#       <td>0.461066</td>
#       <td>0.538934</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.116057</td>
#       <td>2.575853</td>
#       <td>0.456967</td>
#       <td>0.543033</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.112343</td>
#       <td>2.568532</td>
#       <td>0.465164</td>
#       <td>0.534836</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.104123</td>
#       <td>2.544420</td>
#       <td>0.461066</td>
#       <td>0.538934</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.102925</td>
#       <td>2.520418</td>
#       <td>0.459016</td>
#       <td>0.540984</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.097531</td>
#       <td>2.566415</td>
#       <td>0.461066</td>
#       <td>0.538934</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.096923</td>
#       <td>2.560636</td>
#       <td>0.454918</td>
#       <td>0.545082</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.093041</td>
#       <td>2.574417</td>
#       <td>0.467213</td>
#       <td>0.532787</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.088831</td>
#       <td>2.573637</td>
#       <td>0.463115</td>
#       <td>0.536885</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.085934</td>
#       <td>2.574479</td>
#       <td>0.461066</td>
#       <td>0.538934</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.084682</td>
#       <td>2.558853</td>
#       <td>0.461066</td>
#       <td>0.538934</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.081360</td>
#       <td>2.588480</td>
#       <td>0.459016</td>
#       <td>0.540984</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()

# %%
preds, y, losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(learn, preds, y, losses)
interp.plot_top_losses(9)

# %%
learn.predict(open_image('st.JPG'))
# Out:
# (Category Sc,
#  tensor(9),
#  tensor([0.0498, 0.0370, 0.0021, 0.0007, 0.0030, 0.1229, 0.0020, 0.0013, 0.1750,
#          0.5858, 0.0205]))

# %%
import torch.onnx
from torch.autograd import Variable
dummy_input = Variable(torch.randn(1, 3, 64, 64)).cuda().half()
torch.onnx.export(learn.model, dummy_input, "model.onnx")

# %%
netron.start("model.onnx")
# Out:
# Stopping http://localhost:8080
# Serving 'model.onnx' at http://localhost:8080
